# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("training.csv")
df
# categorical_columns = ['ffs_frac_type', 'bin_lateral_length', 
#                         'relative_well_position', 'batch_frac_classification', 'well_family_relationship', 'well_family_relationship']
# encoder = OneHotEncoder(sparse=False)
# encoded_data = encoder.fit_transform(df[categorical_columns])
# encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_columns))
# df = pd.concat([df.drop(columns=categorical_columns), encoded_df], axis=1)
# df
# Out:
#        Unnamed: 0    surface_x    surface_y         bh_x         bh_y  \
# 0               0  1383493.751  717329.2368  1382854.564  712767.3700
# 1               1  1380344.035  711916.2732  1379738.429  707860.5643
# 2               2  1379915.895  717845.0063  1379274.644  713471.9952
# 3               3  1383567.443  706640.2010  1382891.477  702068.3838
# 4               4  1378962.585  702623.9787  1379643.546  707204.9131
# ...           ...          ...          ...          ...          ...
# 29687       30087  1441088.593  978921.8705  1432758.032  979984.5869
# 29688       30088  1513299.189  976157.4486  1519890.072  975148.4820
# 29689       30089  1458652.142  972862.2346  1453129.889  973195.0998
# 29690       30090  1463417.436  972485.8276  1468807.765  971564.9743
# 29691       30091  1394335.017  947368.7697  1400741.808  946305.1175
#
#        standardized_operator_name  gross_perforated_length  number_of_stages  \
# ...

# %%
df.to_csv("onehotencoded.csv")

# %%
df_onn = df[df['OilPeakRate'].notnull()]
#df_onn = df_onn0[df_onn0['relative_well_position'] == 'Inner Well']
df_onn2 = df[df['proppant_intensity'] < 10000]
(df_onn)
# Out:
#        Unnamed: 0     surface_x     surface_y          bh_x          bh_y  \
# 0               0  1.383494e+06  7.173292e+05  1.382855e+06  7.127674e+05
# 1               1  1.380344e+06  7.119163e+05  1.379738e+06  7.078606e+05
# 2               2  1.379916e+06  7.178450e+05  1.379275e+06  7.134720e+05
# 3               3  1.383567e+06  7.066402e+05  1.382891e+06  7.020684e+05
# 4               4  1.378963e+06  7.026240e+05  1.379644e+06  7.072049e+05
# ...           ...           ...           ...           ...           ...
# 29432       29432  9.477118e+05  1.057502e+06  9.435419e+05  1.059277e+06
# 29433       29433  9.593475e+05  1.033564e+06  9.637629e+05  1.031391e+06
# 29434       29434  9.669162e+05  1.057804e+06  9.709082e+05  1.056045e+06
# 29435       29435  9.462629e+05  1.034169e+06  9.525089e+05  1.031066e+06
# 29436       29436  9.467048e+05  1.035064e+06  9.529474e+05  1.031939e+06
#
#        standardized_operator_name  gross_perforated_length  number_of_stages  \
# ...

# %%
df_pi = df_onn2[df_onn2['proppant_intensity'].notnull()]
plt.scatter(df_pi['proppant_intensity'], df_pi['OilPeakRate'])
plt.xlabel('proppant intensity')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_gpf = df_onn[df_onn['gross_perforated_length'].notnull()]
plt.scatter(df_gpf['gross_perforated_length'], df_gpf['OilPeakRate'])
df_gpf600 = df_gpf[df_gpf['OilPeakRate'] > 600]
plt.scatter(df_gpf600['gross_perforated_length'], df_gpf600['OilPeakRate'])

# %%
df_ffi = df_onn[df_onn['frac_fluid_intensity'].notnull()]
plt.scatter(df_ffi['frac_fluid_intensity'], df_ffi['OilPeakRate'])
plt.xlabel('frac fluid intensity')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_tf = df_onn[df_onn['total_fluid'].notnull()]
plt.scatter(df_tf['total_fluid'], df_tf['OilPeakRate'])
plt.xlabel('total fluid')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_tp = df_onn[df_onn['total_proppant'].notnull()]
plt.scatter(df_tp['total_proppant'], df_tp['OilPeakRate'])
plt.xlabel('total proppant')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_hi = df_tp[df_tp['total_fluid'].notnull()]
max_prop = max(df_hi['total_proppant'])
df_hi = df_hi[df_hi['total_proppant'] < max_prop]
plt.scatter(df_hi['total_proppant'], df_hi['total_fluid'])
plt.xlabel('total proppant')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
# df_ft = df_onn[df_onn['ffs_frac_type'].notnull()]
# plt.scatter(df_ft['ffs_frac_type'], df_ft['OilPeakRate'])
# plt.xlabel('ffs frac type')
# plt.ylabel('oil peak rate')

# %%
df_tvd = df_onn[df_onn['true_vertical_depth'].notnull()]
#df_tvd2 = df_tvd[df_tvd['true_vertical_depth']]
plt.scatter(df_tvd['true_vertical_depth'], df_tvd['OilPeakRate'])
plt.xlabel('true vertical depth')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_ns = df_onn[df_onn['number_of_stages'].notnull()]
plt.scatter(df_ns['number_of_stages'], df_ns['OilPeakRate'])
plt.xlabel('number of stages')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_asl = df_onn[df_onn['average_stage_length'].notnull()]
plt.scatter(df_asl['average_stage_length'], df_asl['OilPeakRate'])
plt.xlabel('average stage length')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_aps = df_onn[df_onn['average_proppant_per_stage'].notnull()]
plt.scatter(df_aps['average_proppant_per_stage'], df_aps['OilPeakRate'])
plt.xlabel('average proppant per stage')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_pfr = df_onn[df_onn['proppant_to_frac_fluid_ratio'].notnull()]
df_pfr2 = df_pfr[df_pfr['proppant_to_frac_fluid_ratio'] < 2]
plt.scatter(df_pfr2['proppant_to_frac_fluid_ratio'], df_pfr2['OilPeakRate'])
plt.xlabel('proppant to frac fluid ratio')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_afs = df_onn[df_onn['average_frac_fluid_per_stage'].notnull()]
plt.scatter(df_afs['average_frac_fluid_per_stage'], df_afs['OilPeakRate'])
plt.xlabel('average frac fluid per stage')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_hello = df_afs[df_afs['average_proppant_per_stage'].notnull()]
plt.scatter(df_hello['average_frac_fluid_per_stage'], df_hello['average_proppant_per_stage'])

# %%
df_fpr = df_onn[df_onn['frac_fluid_to_proppant_ratio'].notnull()]
#df_pfr2 = df_pfr[df_pfr['frac_fluid_to_proppant_ratio'] < 2]
plt.scatter(df_fpr['frac_fluid_to_proppant_ratio'], df_fpr['OilPeakRate'])
plt.xlabel('frac fluid to proppant ratio')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
df_bll = df_onn[df_onn['bin_lateral_length'].notnull()]
plt.scatter(df_bll['bin_lateral_length'], df_bll['OilPeakRate'])
plt.xlabel('bin lateral length')
plt.ylabel('oil peak rate')
# Out:
# Text(0, 0.5, 'oil peak rate')

# %%
def graphThis(x):
    df_filler = df_onn[df_onn[x].notnull()]
    plt.scatter(df_filler[x], df_filler['OilPeakRate'])
    plt.xlabel(x)
    plt.ylabel("Oil Peak Rate")

# %%
columns = list(df_onn.columns.values)
columns.remove("pad_id")
columns.remove("standardized_operator_name")
columns.pop(0)
columns
# Out:
# ['surface_x',
#  'surface_y',
#  'bh_x',
#  'bh_y',
#  'gross_perforated_length',
#  'number_of_stages',
#  'total_proppant',
#  'total_fluid',
#  'true_vertical_depth',
#  'ffs_frac_type',
#  'proppant_intensity',
#  'frac_fluid_intensity',
#  'average_stage_length',
#  'average_proppant_per_stage',
#  'average_frac_fluid_per_stage',
#  'proppant_to_frac_fluid_ratio',
#  'frac_fluid_to_proppant_ratio',
#  'bin_lateral_length',
#  'relative_well_position',
#  'batch_frac_classification',
#  'well_family_relationship',
#  'frac_type',
#  'frac_seasoning',
#  'horizontal_midpoint_x',
#  'horizontal_midpoint_y',
#  'horizontal_toe_x',
#  'horizontal_toe_y',
#  'OilPeakRate']

# %%
graphThis("surface_x")

# %%
graphThis("surface_y")

# %%
graphThis("bh_x")
graphThis("surface_x")

# %%
graphThis("bh_y")

# %%
graphThis("relative_well_position")

# %%
graphThis("batch_frac_classification")

# %%
graphThis("well_family_relationship")

# %%
graphThis("frac_type")

# %%
graphThis("frac_seasoning")

# %%
graphThis("horizontal_midpoint_x")

# %%
graphThis("horizontal_midpoint_y")

# %%
graphThis("horizontal_toe_x")

# %%
graphThis("horizontal_toe_y")

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#        Unnamed: 0     surface_x     surface_y          bh_x          bh_y  \
# 344           344  1.032837e+06  6.980786e+05  1.028268e+06  6.988475e+05
# 347           347  1.028373e+06  7.056649e+05  1.023864e+06  7.062604e+05
# 512           512  1.329694e+06  6.050415e+05  1.330348e+06  6.096869e+05
# 540           540  1.070312e+06  7.676331e+05  1.077924e+06  7.665593e+05
# 547           547  1.070326e+06  7.676810e+05  1.078025e+06  7.672044e+05
# ...           ...           ...           ...           ...           ...
# 29410       29410  9.304857e+05  1.057307e+06  9.286405e+05  1.058090e+06
# 29424       29424  9.328000e+05  1.058747e+06  9.308070e+05  1.058564e+06
# 29426       29426  9.313518e+05  1.060801e+06  9.291128e+05  1.059925e+06
# 29428       29428  9.326688e+05  1.059044e+06  9.321407e+05  1.061026e+06
# 29431       29431  9.411536e+05  9.364229e+05  9.372790e+05  9.384046e+05
#
#        standardized_operator_name  gross_perforated_length  number_of_stages  \
# ...
